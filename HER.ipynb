# %%
# %pip install git+https://github.com/patrolSU2019/bbrl_gym.git

# %%
import matplotlib.pyplot as plt
from bbrl_gym.envs.maze_mdp import MazeMDPEnv
import gym
import bbrl_gym
from algo.QL_HER import QLearingHER
# Out:
# Matplotlib backend: module://matplotlib_inline.backend_inline

# %%
env = gym.make("MazeMDP-v0", kwargs={"width": 5, "height": 5, "ratio": 0.2})
env.reset()
env.init_draw("The maze")
env.mdp.plotter.using_notebook = False
algo = QLearingHER(env, max_episodes=1500, batch_size=128, her_k=4, buffer_size=800,max_steps=50,epsilon=0.05)
q_list, time_list = algo.train()
algo.render_policy()

plt.plot(range(len(q_list)), q_list)
plt.xlabel("Episodes")
plt.ylabel("Q-Norm")
plt.show()
plt.plot(range(len(time_list)), time_list)
plt.xlabel("Episodes")
plt.ylabel("Steps to goal")
plt.show()
# Out:
# Output()
# Iteration 0: 100%|██████████| 150/150 [00:00<00:00, 1005.52it/s, episode=150, q_norm=12.610]
# Iteration 1: 100%|██████████| 150/150 [00:00<00:00, 1570.25it/s, episode=300, q_norm=15.385]
# Iteration 2: 100%|██████████| 150/150 [00:00<00:00, 1745.77it/s, episode=450, q_norm=16.646]
# Iteration 3: 100%|██████████| 150/150 [00:00<00:00, 1679.62it/s, episode=600, q_norm=17.360]
# Iteration 4: 100%|██████████| 150/150 [00:00<00:00, 1747.09it/s, episode=750, q_norm=17.905]
# Iteration 5: 100%|██████████| 150/150 [00:00<00:00, 1839.31it/s, episode=900, q_norm=18.269]
# Iteration 6: 100%|██████████| 150/150 [00:00<00:00, 1795.20it/s, episode=1050, q_norm=18.758]
# Iteration 7: 100%|██████████| 150/150 [00:00<00:00, 1784.04it/s, episode=1200, q_norm=18.975]
# Iteration 8: 100%|██████████| 150/150 [00:00<00:00, 1802.86it/s, episode=1350, q_norm=19.237]
# Iteration 9: 100%|██████████| 150/150 [00:00<00:00, 1849.64it/s, episode=1500, q_norm=19.592]
